# %%
import numpy as np

# %%
def extract_buried_points(subunit_coords, complex_coords, threshold):

    '''Function that takes as input the coordinates of two similar pointclouds (one subunit and
    one complex involving that subunit) and a threshold. Returns a list of indeces indicating 
    which points of the first pointcloud (subunit) are more than an certain distance (threshold)
    away from any point in the second pointcloud. These points are "buried" in the complex.'''

    from sklearn.neighbors import NearestNeighbors
    
    neigh = NearestNeighbors(n_neighbors=1)
    neigh.fit(complex_coords) 

    buried= []
    largest_dist = 0
    for i in range(len(subunit_coords)):
        if (dist := neigh.kneighbors([subunit_coords[i]])[0][0][0]) > threshold:
        #if neigh.kneighbors([subunit_coords[i]])[0][0][0] > threshold:
            buried.append(i)
            if dist > largest_dist:
                largest_dist = dist
    return buried

# %% [markdown]
# ### Extract buried region and save data in protein object

# %%
import numpy as np
import os
from helper_functions import load_object, save_object
from c_ProteinGraph import ProteinGraph
from sklearn.neighbors import NearestNeighbors

path = 'C:/Users/david/pyproj/pyg/adl/surfaces_graphs/'
path_list = [file[0:-4] for file in os.listdir(path)]

dest_dir = 'C:/Users/david/OneDrive - ZHAW/ProteinSurfaces/surfaces_graphs_iface/'

threshold = 1.5

complex_files_lists = list(np.load('complexes_names.npy', allow_pickle=True))

for i, complex_list in enumerate(complex_files_lists):
    if complex_list[0][0:-4] not in path_list: continue
    subunit1 = load_object(path + complex_list[0][0:-3] + 'pkl')

    if complex_list[1][0:-4] not in path_list: continue
    subunit2 = load_object(path + complex_list[1][0:-3] + 'pkl')

    if complex_list[2][0:-4] not in path_list: continue
    complex = load_object(path + complex_list[2][0:-3] + 'pkl')

    subunit1_iface_idx = extract_buried_points(subunit1.pos, complex.pos, threshold)
    subunit2_iface_idx = extract_buried_points(subunit2.pos, complex.pos, threshold)


    ## If the interface is too large, skip this complex
    if len(subunit1_iface_idx) > 300 or len(subunit2_iface_idx) > 300: 
        continue

    ## If the interface is too small, skip this complex
    if len(subunit1_iface_idx) < 50 or len(subunit2_iface_idx) < 50: 
        continue

    subunit1_iface_pos = subunit1.pos[subunit1_iface_idx]
    subunit2_iface_pos = subunit2.pos[subunit2_iface_idx]

    merged_iface = np.concatenate((subunit1_iface_pos, subunit2_iface_pos))
    mean_iface_pos = np.mean(merged_iface, axis = 0)

    neigh1 = NearestNeighbors(n_neighbors=1)

    neigh1.fit(subunit1_iface_pos)
    ix = neigh1.kneighbors([mean_iface_pos], return_distance=False)[0][0]
    subunit1_center_idx = subunit1_iface_idx[ix]
    subunit1_center_pos = subunit1_iface_pos[ix]

    neigh1.fit(subunit2_iface_pos)
    ix = neigh1.kneighbors([mean_iface_pos], return_distance=False)[0][0]
    subunit2_center_idx = subunit2_iface_idx[ix]
    subunit2_center_pos = subunit2_iface_pos[ix]

    # save the new data in the protein objects

    subunit1.iface_idx = subunit1_iface_idx
    subunit1.iface_pos = subunit1_iface_pos
    subunit1.iface_center = (subunit1_center_idx, subunit1_center_pos)

    subunit2.iface_idx = subunit2_iface_idx
    subunit2.iface_pos = subunit2_iface_pos
    subunit2.iface_center = (subunit2_center_idx, subunit2_center_pos)

    save_object(subunit1, dest_dir + complex_list[0][0:-3] + 'pkl')
    print(f'Protein {complex_list[0][0:-3]} saved')
    save_object(subunit2, dest_dir + complex_list[1][0:-3] + 'pkl')
    print(f'Protein {complex_list[1][0:-3]} saved')
# Out:
# Protein 1A99_D. saved
# Protein 1A99_C. saved
# Protein 1ACB_I. saved
# Protein 1ACB_E. saved
# Protein 1BCP_L. saved
# Protein 1BCP_H. saved
# Protein 1BK6_E. saved
# Protein 1BK6_B. saved
# Protein 1BVK_F. saved
# Protein 1BVK_DE. saved
# Protein 1C8N_C. saved
# Protein 1C8N_A. saved
# Protein 1CBW_D. saved
# Protein 1CBW_ABC. saved
# Protein 1D2Z_B. saved
# Protein 1D2Z_A. saved
# Protein 1DBW_B. saved
# Protein 1DBW_A. saved
# Protein 1DFJ_I. saved
# Protein 1DFJ_E. saved
# Protein 1DK4_B. saved
# Protein 1DK4_A. saved
# Protein 1DM5_F. saved
# Protein 1DM5_E. saved
# Protein 1DSX_H. saved
# Protein 1DSX_E. saved
# Protein 1EAI_C. saved
# Protein 1EAI_A. saved
# Protein 1EJA_B. saved
# Protein 1EJA_A. saved
# Protein 1EMU_B. saved
# Protein 1EMU_A. saved
# Protein 1EMV_B. saved
# Protein 1EMV_A. saved
# Protein 1EZI_B. saved
# Protein 1EZI_A. saved
# Protein 1F5R_I. saved
# Protein 1F5R_A. saved
# Protein 1FGL_B. saved
# Protein 1FGL_A. saved
# Protein 1FMO_I. saved
# Protein 1FMO_E. saved
# Protein 1FNS_A. saved
# Protein 1FNS_HL. saved
# Protein 1FQJ_B. saved
# Protein 1FQJ_A. saved
# Protein 1FT8_C. saved
# Protein 1FT8_B. saved
# Protein 1FUJ_C. saved
# Protein 1FUJ_B. saved
# Protein 1G6V_K. saved
# Protein 1G6V_A. saved
# Protein 1G9I_I. saved
# Protein 1G9I_E. saved
# Protein 1GQA_D. saved
# Protein 1GQA_A. saved
# Protein 1GVM_F. saved
# Protein 1GVM_E. saved
# Protein 1H3L_B. saved
# Protein 1H3L_A. saved
# Protein 1H59_B. saved
# Protein 1H59_A. saved
# Protein 1HAA_B. saved
# Protein 1HAA_A. saved
# Protein 1HBT_I. saved
# Protein 1HBT_H. saved
# Protein 1HE1_C. saved
# Protein 1HE1_A. saved
# Protein 1HEZ_E. saved
# Protein 1HEZ_BA. saved
# Protein 1HF2_D. saved
# Protein 1HF2_C. saved
# Protein 1HJR_D. saved
# Protein 1HJR_B. saved
# Protein 1IVO_B. saved
# Protein 1IVO_A. saved
# Protein 1J2U_D. saved
# Protein 1J2U_C. saved
# Protein 1J7D_B. saved
# Protein 1J7D_A. saved
# Protein 1JFI_C. saved
# Protein 1JFI_B. saved
# Protein 1JK9_D. saved
# Protein 1JK9_B. saved
# Protein 1K4C_C. saved
# Protein 1K4C_AB. saved
# Protein 1K74_DE. saved
# Protein 1K74_AB. saved
# Protein 1KAC_B. saved
# Protein 1KAC_A. saved
# Protein 1KSH_B. saved
# Protein 1KSH_A. saved
# Protein 1KXT_B. saved
# Protein 1KXT_A. saved
# Protein 1L6X_B. saved
# Protein 1L6X_A. saved
# Protein 1LLI_B. saved
# Protein 1LLI_A. saved
# Protein 1M9F_C. saved
# Protein 1M9F_B. saved
# Protein 1MDY_B. saved
# Protein 1MDY_A. saved
# Protein 1ML1_E. saved
# Protein 1ML1_A. saved
# Protein 1MQS_B. saved
# Protein 1MQS_A. saved
# Protein 1N9S_G. saved
# Protein 1N9S_F. saved
# Protein 1NB5_I. saved
# Protein 1NB5_AP. saved
# Protein 1NF3_C. saved
# Protein 1NF3_A. saved
# Protein 1NH2_D. saved
# Protein 1NH2_B. saved
# Protein 1NP8_B. saved
# Protein 1NP8_A. saved
# Protein 1NPO_C. saved
# Protein 1NPO_A. saved
# Protein 1NPP_B. saved
# Protein 1NPP_A. saved
# Protein 1O57_D. saved
# Protein 1O57_C. saved
# Protein 1OC0_B. saved
# Protein 1OC0_A. saved
# Protein 1ORQ_C. saved
# Protein 1ORQ_BA. saved
# Protein 1OSP_O. saved
# Protein 1OSP_HL. saved
# Protein 1OX9_L. saved
# Protein 1OX9_D. saved
# Protein 1P69_B. saved
# Protein 1P69_A. saved
# Protein 1P8C_E. saved
# Protein 1P8C_A. saved
# Protein 1PM3_B. saved
# Protein 1PM3_A. saved
# Protein 1PYT_C. saved
# Protein 1PYT_A. saved
# Protein 1Q23_I. saved
# Protein 1Q23_H. saved
# Protein 1Q4Q_Q. saved
# Protein 1Q4Q_D. saved
# Protein 1QE6_D. saved
# Protein 1QE6_C. saved
# Protein 1QG7_B. saved
# Protein 1QG7_A. saved
# Protein 1QOL_F. saved
# Protein 1QOL_A. saved
# Protein 1R3K_C. saved
# Protein 1R3K_B. saved
# Protein 1R5I_D. saved
# Protein 1R5I_A. saved
# Protein 1R7A_B. saved
# Protein 1R7A_A. saved
# Protein 1RDF_C. saved
# Protein 1RDF_B. saved
# Protein 1RPN_D. saved
# Protein 1RPN_A. saved
# Protein 1RPQ_Y. saved
# Protein 1RPQ_C. saved
# Protein 1RV6_X. saved
# Protein 1RV6_VW. saved
# Protein 1SGJ_B. saved
# Protein 1SGJ_A. saved
# Protein 1SOJ_J. saved
# Protein 1SOJ_A. saved
# Protein 1SPB_S. saved
# Protein 1SPB_P. saved
# Protein 1STM_E. saved
# Protein 1STM_D. saved
# Protein 1SZH_B. saved
# Protein 1SZH_A. saved
# Protein 1T0B_C. saved
# Protein 1T0B_A. saved
# Protein 1T1V_B. saved
# Protein 1T1V_A. saved
# Protein 1T3L_B. saved
# Protein 1T3L_A. saved
# Protein 1T6G_D. saved
# Protein 1T6G_B. saved
# Protein 1T7P_B. saved
# Protein 1T7P_A. saved
# Protein 1TAW_B. saved
# Protein 1TAW_A. saved
# Protein 1TO0_H. saved
# Protein 1TO0_G. saved
# Protein 1TX4_B. saved
# Protein 1TX4_A. saved
# Protein 1TY4_C. saved
# Protein 1TY4_A. saved
# Protein 1TZS_P. saved
# Protein 1TZS_A. saved
# Protein 1U2E_C. saved
# Protein 1U2E_A. saved
# Protein 1U2V_G. saved
# Protein 1U2V_C. saved
# Protein 1U8T_F. saved
# Protein 1U8T_B. saved
# Protein 1UAD_C. saved
# Protein 1UAD_A. saved
# Protein 1UR6_B. saved
# Protein 1UR6_A. saved
# Protein 1UWG_X. saved
# Protein 1UWG_L. saved
# Protein 1V54_X. saved
# Protein 1V54_Q. saved
# Protein 1VFB_C. saved
# Protein 1VFB_AB. saved
# Protein 1VG0_B. saved
# Protein 1VG0_A. saved
# Protein 1VH5_B. saved
# Protein 1VH5_A. saved
# Protein 1VPP_Y. saved
# Protein 1VPP_W. saved
# Protein 1W39_C. saved
# Protein 1W39_A. saved
# Protein 1WEJ_F. saved
# Protein 1WEJ_HL. saved
# Protein 1WO8_C. saved
# Protein 1WO8_B. saved
# Protein 1WOQ_B. saved
# Protein 1WOQ_A. saved
# Protein 1WR6_E. saved
# Protein 1WR6_A. saved
# Protein 1X9J_H. saved
# Protein 1X9J_G. saved
# Protein 1XFS_B. saved
# Protein 1XFS_A. saved
# Protein 1XKP_C. saved
# Protein 1XKP_B. saved
# Protein 1Y3A_F. saved
# Protein 1Y3A_B. saved
# Protein 1Y4A_I. saved
# Protein 1Y4A_E. saved
# Protein 1Y64_B. saved
# Protein 1Y64_A. saved
# Protein 1Y6K_R. saved
# Protein 1Y6K_L. saved
# Protein 1Y6M_R. saved
# Protein 1Y6M_L. saved
# Protein 1Y8N_B. saved
# Protein 1Y8N_A. saved
# Protein 1YAF_C. saved
# Protein 1YAF_A. saved
# Protein 1YBG_B. saved
# Protein 1YBG_A. saved
# Protein 1YC8_B. saved
# Protein 1YC8_A. saved
# Protein 1YCS_B. saved
# Protein 1YCS_A. saved
# Protein 1YF9_B. saved
# Protein 1YF9_A. saved
# Protein 1YJD_C. saved
# Protein 1YJD_HL. saved
# Protein 1YVI_B. saved
# Protein 1YVI_A. saved
# Protein 1YWH_F. saved
# Protein 1YWH_E. saved
# Protein 1Z6Y_B. saved
# Protein 1Z6Y_A. saved
# Protein 1Z82_B. saved
# Protein 1Z82_A. saved
# Protein 1ZA3_R. saved
# Protein 1ZA3_HL. saved
# Protein 1ZC4_D. saved
# Protein 1ZC4_B. saved
# Protein 1ZHI_B. saved
# Protein 1ZHI_A. saved
# Protein 1ZJD_B. saved
# Protein 1ZJD_A. saved
# Protein 2A5T_B. saved
# Protein 2A5T_A. saved
# Protein 2A5Z_C. saved
# Protein 2A5Z_A. saved
# Protein 2ABZ_E. saved
# Protein 2ABZ_B. saved
# Protein 2AEP_A. saved
# Protein 2AEP_HL. saved
# Protein 2AQ1_B. saved
# Protein 2AQ1_A. saved
# Protein 2AUH_B. saved
# Protein 2AUH_A. saved
# Protein 2AVU_F. saved
# Protein 2AVU_D. saved
# Protein 2AW6_F. saved
# Protein 2AW6_A. saved
# Protein 2B0Z_B. saved
# Protein 2B0Z_A. saved
# Protein 2B43_D. saved
# Protein 2B43_B. saved
# Protein 2BBA_P. saved
# Protein 2BBA_A. saved
# Protein 2BUJ_B. saved
# Protein 2BUJ_A. saved
# Protein 2C0L_B. saved
# Protein 2C0L_A. saved
# Protein 2C57_C. saved
# Protein 2C57_A. saved
# Protein 2CO5_B. saved
# Protein 2CO5_A. saved
# Protein 2CS7_C. saved
# Protein 2CS7_A. saved
# Protein 2DG0_H. saved
# Protein 2DG0_E. saved
# Protein 2DJF_B. saved
# Protein 2DJF_A. saved
# Protein 2DUP_B. saved
# Protein 2DUP_A. saved
# Protein 2EAY_B. saved
# Protein 2EAY_A. saved
# Protein 2EH8_P. saved
# Protein 2EH8_L. saved
# Protein 2EKY_D. saved
# Protein 2EKY_B. saved
# Protein 2ERJ_D. saved
# Protein 2ERJ_A. saved
# Protein 2F31_B. saved
# Protein 2F31_A. saved
# Protein 2F4E_B. saved
# Protein 2F4E_A. saved
# Protein 2F9Z_C. saved
# Protein 2F9Z_A. saved
# Protein 2FLH_D. saved
# Protein 2FLH_C. saved
# Protein 2FMI_B. saved
# Protein 2FMI_A. saved
# Protein 2FTM_B. saved
# Protein 2FTM_A. saved
# Protein 2FTX_B. saved
# Protein 2FTX_A. saved
# Protein 2G2W_B. saved
# Protein 2G2W_A. saved
# Protein 2G47_C. saved
# Protein 2G47_A. saved
# Protein 2GDG_C. saved
# Protein 2GDG_B. saved
# Protein 2GKW_B. saved
# Protein 2GKW_A. saved
# Protein 2GPV_E. saved
# Protein 2GPV_A. saved
# Protein 2GTP_D. saved
# Protein 2GTP_A. saved
# Protein 2H19_B. saved
# Protein 2H19_A. saved
# Protein 2HD3_F. saved
# Protein 2HD3_E. saved
# Protein 2HE2_B. saved
# Protein 2HE2_A. saved
# Protein 2HQH_F. saved
# Protein 2HQH_B. saved
# Protein 2HRV_B. saved
# Protein 2HRV_A. saved
# Protein 2HTH_B. saved
# Protein 2HTH_A. saved
# Protein 2HWJ_C. saved
# Protein 2HWJ_A. saved
# Protein 2HWW_B. saved
# Protein 2HWW_A. saved
# Protein 2HZB_B. saved
# Protein 2HZB_A. saved
# Protein 2I04_B. saved
# Protein 2I04_A. saved
# Protein 2I25_N. saved
# Protein 2I25_L. saved
# Protein 2I26_N. saved
# Protein 2I26_L. saved
# Protein 2I9L_L. saved
# Protein 2I9L_HG. saved
# Protein 2IJ0_C. saved
# Protein 2IJ0_B. saved
# Protein 2IV8_P. saved
# Protein 2IV8_A. saved
# Protein 2IY1_B. saved
# Protein 2IY1_A. saved
# Protein 2J0T_D. saved
# Protein 2J0T_A. saved
# Protein 2J59_M. saved
# Protein 2J59_A. saved
# Protein 2J7Q_D. saved
# Protein 2J7Q_C. saved
# Protein 2JG8_F. saved
# Protein 2JG8_D. saved
# Protein 2L0I_B. saved
# Protein 2L0I_A. saved
# Protein 2MRO_B. saved
# Protein 2MRO_A. saved
# Protein 2NR6_B. saved
# Protein 2NR6_FE. saved
# Protein 2O9Q_C. saved
# Protein 2O9Q_A. saved
# Protein 2OK2_B. saved
# Protein 2OK2_A. saved
# Protein 2OKF_B. saved
# Protein 2OKF_A. saved
# Protein 2OOB_B. saved
# Protein 2OOB_A. saved
# Protein 2OPD_B. saved
# Protein 2OPD_A. saved
# Protein 2OPI_B. saved
# Protein 2OPI_A. saved
# Protein 2OSZ_C. saved
# Protein 2OSZ_A. saved
# Protein 2OYY_B. saved
# Protein 2OYY_A. saved
# Protein 2P42_B. saved
# Protein 2P42_A. saved
# Protein 2P44_B. saved
# Protein 2P44_A. saved
# Protein 2P49_B. saved
# Protein 2P49_A. saved
# Protein 2P4A_B. saved
# Protein 2P4A_A. saved
# Protein 2P4R_T. saved
# Protein 2P4R_A. saved
# Protein 2P6B_E. saved
# Protein 2P6B_A. saved
# Protein 2P9P_G. saved
# Protein 2P9P_F. saved
# Protein 2PEB_B. saved
# Protein 2PEB_A. saved
# Protein 2PKG_C. saved
# Protein 2PKG_A. saved
# Protein 2POB_B. saved
# Protein 2POB_A. saved
# Protein 2PQN_B. saved
# Protein 2PQN_A. saved
# Protein 2PRO_B. saved
# Protein 2PRO_A. saved
# Protein 2PSM_F. saved
# Protein 2PSM_A. saved
# Protein 2PTC_I. saved
# Protein 2PTC_E. saved
# Protein 2PUK_G. saved
# Protein 2PUK_E. saved
# Protein 2PZH_D. saved
# Protein 2PZH_A. saved
# Protein 2Q0O_B. saved
# Protein 2Q0O_A. saved
# Protein 2Q7F_B. saved
# Protein 2Q7F_A. saved
# Protein 2QAZ_D. saved
# Protein 2QAZ_C. saved
# Protein 2QFC_B. saved
# Protein 2QFC_A. saved
# Protein 2QJA_D. saved
# Protein 2QJA_B. saved
# Protein 2QKI_G. saved
# Protein 2QKI_A. saved
# Protein 2QLC_C. saved
# Protein 2QLC_B. saved
# Protein 2QR0_V. saved
# Protein 2QR0_XW. saved
# Protein 2R56_A. saved
# Protein 2R56_HL. saved
# Protein 2R6O_B. saved
# Protein 2R6O_A. saved
# Protein 2R8Q_B. saved
# Protein 2R8Q_A. saved
# Protein 2RAX_F. saved
# Protein 2RAX_E. saved
# Protein 2RD7_C. saved
# Protein 2RD7_A. saved
# Protein 2UUY_B. saved
# Protein 2UUY_A. saved
# Protein 2UZC_B. saved
# Protein 2UZC_A. saved
# Protein 2V54_B. saved
# Protein 2V54_A. saved
# Protein 2V6B_D. saved
# Protein 2V6B_C. saved
# Protein 2V92_E. saved
# Protein 2V92_B. saved
# Protein 2V9P_L. saved
# Protein 2V9P_G. saved
# Protein 2VDB_B. saved
# Protein 2VDB_A. saved
# Protein 2VFX_J. saved
# Protein 2VFX_C. saved
# Protein 2VLN_B. saved
# Protein 2VLN_A. saved
# Protein 2VLP_B. saved
# Protein 2VLP_A. saved
# Protein 2VOH_B. saved
# Protein 2VOH_A. saved
# Protein 2VUO_B. saved
# Protein 2VUO_A. saved
# Protein 2VXB_B. saved
# Protein 2VXB_A. saved
# Protein 2W69_D. saved
# Protein 2W69_A. saved
# Protein 2W85_B. saved
# Protein 2W85_A. saved
# Protein 2WFL_B. saved
# Protein 2WFL_A. saved
# Protein 2WG4_B. saved
# Protein 2WG4_A. saved
# Protein 2WJ0_B. saved
# Protein 2WJ0_A. saved
# Protein 2WL8_C. saved
# Protein 2WL8_A. saved
# Protein 2WWK_T. saved
# Protein 2WWK_O. saved
# Protein 2X9A_D. saved
# Protein 2X9A_C. saved
# Protein 2X9M_D. saved
# Protein 2X9M_B. saved
# Protein 2XQB_A. saved
# Protein 2XQB_HL. saved
# Protein 2XRA_A. saved
# Protein 2XRA_HL. saved
# Protein 2XSO_S. saved
# Protein 2XSO_H. saved
# Protein 2XTT_B. saved
# Protein 2XTT_A. saved
# Protein 2XV6_B. saved
# Protein 2XV6_A. saved
# Protein 2XWT_C. saved
# Protein 2XWT_A. saved
# Protein 2XYR_B. saved
# Protein 2XYR_A. saved
# Protein 2XZE_R. saved
# Protein 2XZE_B. saved
# Protein 2Y0M_B. saved
# Protein 2Y0M_A. saved
# Protein 2YC2_D. saved
# Protein 2YC2_A. saved
# Protein 2YJE_M. saved
# Protein 2YJE_C. saved
# Protein 2YPV_A. saved
# Protein 2YPV_HL. saved
# Protein 2YQ7_B. saved
# Protein 2YQ7_A. saved
# Protein 2YVL_D. saved
# Protein 2YVL_B. saved
# Protein 2Z2S_G. saved
# Protein 2Z2S_E. saved
# Protein 2Z3F_G. saved
# Protein 2Z3F_E. saved
# Protein 2Z7E_C. saved
# Protein 2Z7E_A. saved
# Protein 2Z7F_I. saved
# Protein 2Z7F_E. saved
# Protein 2ZCL_P. saved
# Protein 2ZCL_H. saved
# Protein 2ZME_C. saved
# Protein 2ZME_A. saved
# Protein 2ZMV_B. saved
# Protein 2ZMV_A. saved
# Protein 2ZOQ_B. saved
# Protein 2ZOQ_A. saved
# Protein 2ZUQ_A. saved
# Protein 2ZUQ_CB. saved
# Protein 3A9K_C. saved
# Protein 3A9K_A. saved
# Protein 3ABD_Y. saved
# Protein 3ABD_B. saved
# Protein 3AHS_C. saved
# Protein 3AHS_A. saved
# Protein 3ALZ_B. saved
# Protein 3ALZ_A. saved
# Protein 3B3D_C. saved
# Protein 3B3D_A. saved
# Protein 3B4S_B. saved
# Protein 3B4S_A. saved
# Protein 3B5U_D. saved
# Protein 3B5U_B. saved
# Protein 3B9K_F. saved
# Protein 3B9K_D. saved
# Protein 3BEY_E. saved
# Protein 3BEY_D. saved
# Protein 3BGF_A. saved
# Protein 3BGF_BC. saved
# Protein 3BJB_B. saved
# Protein 3BJB_A. saved
# Protein 3BN3_B. saved
# Protein 3BN3_A. saved
# Protein 3BN9_A. saved
# Protein 3BN9_FE. saved
# Protein 3BNW_B. saved
# Protein 3BNW_A. saved
# Protein 3BPD_G. saved
# Protein 3BPD_F. saved
# Protein 3BRJ_D. saved
# Protein 3BRJ_C. saved
# Protein 3BRT_B. saved
# Protein 3BRT_A. saved
# Protein 3BU5_B. saved
# Protein 3BU5_A. saved
# Protein 3BWU_D. saved
# Protein 3BWU_C. saved
# Protein 3BWV_B. saved
# Protein 3BWV_A. saved
# Protein 3C0B_D. saved
# Protein 3C0B_C. saved
# Protein 3C3R_B. saved
# Protein 3C3R_A. saved
# Protein 3C66_C. saved
# Protein 3C66_A. saved
# Protein 3CBY_B. saved
# Protein 3CBY_A. saved
# Protein 3CDK_C. saved
# Protein 3CDK_A. saved
# Protein 3CE9_D. saved
# Protein 3CE9_A. saved
# Protein 3CKI_B. saved
# Protein 3CKI_A. saved
# Protein 3CVJ_C. saved
# Protein 3CVJ_A. saved
# Protein 3CYJ_B. saved
# Protein 3CYJ_A. saved
# Protein 3D1E_P. saved
# Protein 3D1E_A. saved
# Protein 3D32_D. saved
# Protein 3D32_B. saved
# Protein 3D36_C. saved
# Protein 3D36_A. saved
# Protein 3D5N_I. saved
# Protein 3D5N_H. saved
# Protein 3D7T_B. saved
# Protein 3D7T_A. saved
# Protein 3D8A_G. saved
# Protein 3D8A_F. saved
# Protein 3D9R_C. saved
# Protein 3D9R_B. saved
# Protein 3DCL_B. saved
# Protein 3DCL_A. saved
# Protein 3DDM_C. saved
# Protein 3DDM_B. saved
# Protein 3DEP_B. saved
# Protein 3DEP_A. saved
# Protein 3DGE_D. saved
# Protein 3DGE_B. saved
# Protein 3DI2_B. saved
# Protein 3DI2_A. saved
# Protein 3DI3_B. saved
# Protein 3DI3_A. saved
# Protein 3DLU_B. saved
# Protein 3DLU_A. saved
# Protein 3DNM_B. saved
# Protein 3DNM_A. saved
# Protein 3DOE_B. saved
# Protein 3DOE_A. saved
# Protein 3DQQ_B. saved
# Protein 3DQQ_A. saved
# Protein 3DTO_D. saved
# Protein 3DTO_C. saved
# Protein 3E0J_E. saved
# Protein 3E0J_C. saved
# Protein 3E2U_E. saved
# Protein 3E2U_A. saved
# Protein 3E48_B. saved
# Protein 3E48_A. saved
# Protein 3EAB_G. saved
# Protein 3EAB_A. saved
# Protein 3EDM_D. saved
# Protein 3EDM_B. saved
# Protein 3EO1_CF. saved
# Protein 3EO1_AB. saved
# Protein 3EZY_C. saved
# Protein 3EZY_A. saved
# Protein 3F7G_C. saved
# Protein 3F7G_B. saved
# Protein 3FA9_B. saved
# Protein 3FA9_A. saved
# Protein 3FBN_D. saved
# Protein 3FBN_C. saved
# Protein 3FBZ_C. saved
# Protein 3FBZ_A. saved
# Protein 3FJU_B. saved
# Protein 3FJU_A. saved
# Protein 3FKF_C. saved
# Protein 3FKF_A. saved
# Protein 3FP6_I. saved
# Protein 3FP6_E. saved
# Protein 3FUY_B. saved
# Protein 3FUY_A. saved
# Protein 3G04_C. saved
# Protein 3G04_BA. saved
# Protein 3G13_B. saved
# Protein 3G13_A. saved
# Protein 3G33_C. saved
# Protein 3G33_B. saved
# Protein 3GD1_I. saved
# Protein 3GD1_E. saved
# Protein 3GI9_C. saved
# Protein 3GI9_HL. saved
# Protein 3GJ5_B. saved
# Protein 3GJ5_A. saved
# Protein 3GJ6_B. saved
# Protein 3GJ6_A. saved
# Protein 3GL9_C. saved
# Protein 3GL9_B. saved
# Protein 3GQH_B. saved
# Protein 3GQH_A. saved
# Protein 3GXU_B. saved
# Protein 3GXU_A. saved
# Protein 3H2U_B. saved
# Protein 3H2U_A. saved
# Protein 3H2V_E. saved
# Protein 3H2V_A. saved
# Protein 3H3B_C. saved
# Protein 3H3B_A. saved
# Protein 3H4E_I. saved
# Protein 3H4E_H. saved
# Protein 3HE3_F. saved
# Protein 3HE3_C. saved
# Protein 3HLI_B. saved
# Protein 3HLI_A. saved
# Protein 3HM8_C. saved
# Protein 3HM8_A. saved
# Protein 3HN6_D. saved
# Protein 3HN6_B. saved
# Protein 3HSH_F. saved
# Protein 3HSH_D. saved
# Protein 3HTU_D. saved
# Protein 3HTU_C. saved
# Protein 3HWS_D. saved
# Protein 3HWS_C. saved
# Protein 3I50_E. saved
# Protein 3I50_HL. saved
# Protein 3IAI_D. saved
# Protein 3IAI_A. saved
# Protein 3IB6_D. saved
# Protein 3IB6_B. saved
# Protein 3IBR_B. saved
# Protein 3IBR_A. saved
# Protein 3IKK_B. saved
# Protein 3IKK_A. saved
# Protein 3IT4_D. saved
# Protein 3IT4_B. saved
# Protein 3JUA_D. saved
# Protein 3JUA_C. saved
# Protein 3JVC_C. saved
# Protein 3JVC_A. saved
# Protein 3K2U_A. saved
# Protein 3K2U_HL. saved
# Protein 3K4G_D. saved
# Protein 3K4G_C. saved
# Protein 3K53_B. saved
# Protein 3K53_A. saved
# Protein 3K6C_C. saved
# Protein 3K6C_B. saved
# Protein 3K75_D. saved
# Protein 3K75_B. saved
# Protein 3KH2_E. saved
# Protein 3KH2_A. saved
# Protein 3KL9_J. saved
# Protein 3KL9_I. saved
# Protein 3KVP_F. saved
# Protein 3KVP_A. saved
# Protein 3KYG_B. saved
# Protein 3KYG_A. saved
# Protein 3KYJ_B. saved
# Protein 3KYJ_A. saved
# Protein 3L18_B. saved
# Protein 3L18_A. saved
# Protein 3L9J_T. saved
# Protein 3L9J_C. saved
# Protein 3LB6_C. saved
# Protein 3LB6_A. saved
# Protein 3LBS_B. saved
# Protein 3LBS_A. saved
# Protein 3LFR_B. saved
# Protein 3LFR_A. saved
# Protein 3LLM_B. saved
# Protein 3LLM_A. saved
# Protein 3LNZ_F. saved
# Protein 3LNZ_E. saved
# Protein 3LP6_B. saved
# Protein 3LP6_A. saved
# Protein 3LTE_D. saved
# Protein 3LTE_C. saved
# Protein 3M18_B. saved
# Protein 3M18_A. saved
# Protein 3M6N_C. saved
# Protein 3M6N_B. saved
# Protein 3M85_G. saved
# Protein 3M85_B. saved
# Protein 3M8N_D. saved
# Protein 3M8N_A. saved
# Protein 3ME4_B. saved
# Protein 3ME4_A. saved
# Protein 3MES_B. saved
# Protein 3MES_A. saved
# Protein 3MHP_C. saved
# Protein 3MHP_B. saved
# Protein 3MI8_D. saved
# Protein 3MI8_A. saved
# Protein 3MJH_B. saved
# Protein 3MJH_A. saved
# Protein 3MJQ_B. saved
# Protein 3MJQ_A. saved
# Protein 3ML6_F. saved
# Protein 3ML6_B. saved
# Protein 3MR7_C. saved
# Protein 3MR7_A. saved
# Protein 3MXW_A. saved
# Protein 3MXW_LH. saved
# Protein 3MYR_D. saved
# Protein 3MYR_B. saved
# Protein 3N10_B. saved
# Protein 3N10_A. saved
# Protein 3N4P_B. saved
# Protein 3N4P_A. saved
# Protein 3NHV_B. saved
# Protein 3NHV_A. saved
# Protein 3NKH_B. saved
# Protein 3NKH_A. saved
# Protein 3NL2_F. saved
# Protein 3NL2_B. saved
# Protein 3NMZ_C. saved
# Protein 3NMZ_A. saved
# Protein 3NN2_C. saved
# Protein 3NN2_B. saved
# Protein 3NTE_B. saved
# Protein 3NTE_A. saved
# Protein 3O0L_B. saved
# Protein 3O0L_A. saved
# Protein 3O3Q_C. saved
# Protein 3O3Q_A. saved
# Protein 3OB0_M. saved
# Protein 3OB0_H. saved
# Protein 3OEU_M. saved
# Protein 3OEU_2. saved
# Protein 3OGI_D. saved
# Protein 3OGI_C. saved
# Protein 3OKJ_D. saved
# Protein 3OKJ_C. saved
# Protein 3OL3_B. saved
# Protein 3OL3_A. saved
# Protein 3OMT_B. saved
# Protein 3OMT_A. saved
# Protein 3ON0_D. saved
# Protein 3ON0_A. saved
# Protein 3ON3_B. saved
# Protein 3ON3_A. saved
# Protein 3ONA_B. saved
# Protein 3ONA_A. saved
# Protein 3ONL_B. saved
# Protein 3ONL_A. saved
# Protein 3P30_A. saved
# Protein 3P30_HL. saved
# Protein 3P72_B. saved
# Protein 3P72_A. saved
# Protein 3P95_E. saved
# Protein 3P95_A. saved
# Protein 3P9W_B. saved
# Protein 3P9W_A. saved
# Protein 3PRB_B. saved
# Protein 3PRB_A. saved
# Protein 3PRU_C. saved
# Protein 3PRU_A. saved
# Protein 3PUT_B. saved
# Protein 3PUT_A. saved
# Protein 3PUZ_F. saved
# Protein 3PUZ_B. saved
# Protein 3Q3G_I. saved
# Protein 3Q3G_HF. saved
# Protein 3Q3Y_B. saved
# Protein 3Q3Y_A. saved
# Protein 3QC9_C. saved
# Protein 3QC9_B. saved
# Protein 3QJ7_D. saved
# Protein 3QJ7_A. saved
# Protein 3QQ0_B. saved
# Protein 3QQ0_A. saved
# Protein 3QUM_Q. saved
# Protein 3QUM_KM. saved
# Protein 3QWO_C. saved
# Protein 3QWO_A. saved
# Protein 3R5X_D. saved
# Protein 3R5X_C. saved
# Protein 3R9A_B. saved
# Protein 3R9A_AC. saved
# Protein 3RAM_D. saved
# Protein 3RAM_B. saved
# Protein 3RDZ_C. saved
# Protein 3RDZ_A. saved
# Protein 3REA_B. saved
# Protein 3REA_A. saved
# Protein 3RPX_C. saved
# Protein 3RPX_B. saved
# Protein 3RZW_D. saved
# Protein 3RZW_A. saved
# Protein 3S1J_B. saved
# Protein 3S1J_A. saved
# Protein 3SJH_B. saved
# Protein 3SJH_A. saved
# Protein 3SQO_A. saved
# Protein 3SQO_HL. saved
# Protein 3STB_C. saved
# Protein 3STB_B. saved
# Protein 3SVK_B. saved
# Protein 3SVK_A. saved
# Protein 3TG1_B. saved
# Protein 3TG1_A. saved
# Protein 3TL3_B. saved
# Protein 3TL3_A. saved
# Protein 3TY7_B. saved
# Protein 3TY7_A. saved
# Protein 3U0H_B. saved
# Protein 3U0H_A. saved
# Protein 3U43_B. saved
# Protein 3U43_A. saved
# Protein 3U61_H. saved
# Protein 3U61_F. saved
# Protein 3U8X_B. saved
# Protein 3U8X_A. saved
# Protein 3UIR_C. saved
# Protein 3UIR_A. saved
# Protein 3UKV_B. saved
# Protein 3UKV_A. saved
# Protein 3UL4_B. saved
# Protein 3UL4_A. saved
# Protein 3ULA_D. saved
# Protein 3ULA_A. saved
# Protein 3UO2_B. saved
# Protein 3UO2_A. saved
# Protein 3UVN_D. saved
# Protein 3UVN_C. saved
# Protein 3UZQ_B. saved
# Protein 3UZQ_A. saved
# Protein 3VI4_B. saved
# Protein 3VI4_FE. saved
# Protein 3VYR_B. saved
# Protein 3VYR_A. saved
# Protein 3ZWL_E. saved
# Protein 3ZWL_B. saved
# Protein 3ZZV_B. saved
# Protein 3ZZV_A. saved
# Protein 4AEI_A. saved
# Protein 4AEI_HL. saved
# Protein 4AFQ_C. saved
# Protein 4AFQ_A. saved
# Protein 4AOQ_D. saved
# Protein 4AOQ_A. saved
# Protein 4AQE_B. saved
# Protein 4AQE_A. saved
# Protein 4AWX_B. saved
# Protein 4AWX_A. saved
# Protein 4B1X_M. saved
# Protein 4B1X_B. saved
# Protein 4BFI_B. saved
# Protein 4BFI_A. saved
# Protein 4BOH_B. saved
# Protein 4BOH_A. saved
# Protein 4BZ2_A. saved
# Protein 4BZ2_HL. saved
# Protein 4C4K_T. saved
# Protein 4C4K_O. saved
# Protein 4D0G_C. saved
# Protein 4D0G_A. saved
# Protein 4D3C_A. saved
# Protein 4D3C_HL. saved
# Protein 4DAG_A. saved
# Protein 4DAG_HL. saved
# Protein 4DM8_C. saved
# Protein 4DM8_A. saved
# Protein 4DXA_B. saved
# Protein 4DXA_A. saved
# Protein 4EDX_V. saved
# Protein 4EDX_HL. saved
# Protein 4EHQ_G. saved
# Protein 4EHQ_A. saved
# Protein 4EQA_C. saved
# Protein 4EQA_A. saved
# Protein 4EXP_X. saved
# Protein 4EXP_A. saved
# Protein 4F15_G. saved
# Protein 4F15_HI. saved
# Protein 4F9L_B. saved
# Protein 4F9L_A. saved
# Protein 4FFY_A. saved
# Protein 4FFY_HL. saved
# Protein 4FZA_B. saved
# Protein 4FZA_A. saved
# Protein 4G59_C. saved
# Protein 4G59_A. saved
# Protein 4G7V_S. saved
# Protein 4G7V_HL. saved
# Protein 4GH7_B. saved
# Protein 4GH7_A. saved
# Protein 4GN3_B. saved
# Protein 4GN3_A. saved
# Protein 4HGK_D. saved
# Protein 4HGK_A. saved
# Protein 4HJ0_A. saved
# Protein 4HJ0_PQ. saved
# Protein 4HT1_T. saved
# Protein 4HT1_HL. saved
# Protein 4IZ7_B. saved
# Protein 4IZ7_A. saved
# Protein 4JDT_G. saved
# Protein 4JDT_HL. saved
# Protein 4JLR_S. saved
# Protein 4JLR_HL. saved
# Protein 4K5B_D. saved
# Protein 4K5B_A. saved
# Protein 4K9E_C. saved
# Protein 4K9E_HL. saved
# Protein 4KBB_C. saved
# Protein 4KBB_A. saved
# Protein 4KI5_M. saved
# Protein 4KI5_EF. saved
# Protein 4KJY_B. saved
# Protein 4KJY_A. saved
# Protein 4LGR_B. saved
# Protein 4LGR_A. saved
# Protein 4LMQ_D. saved
# Protein 4LMQ_HL. saved
# Protein 4MJS_B. saved
# Protein 4MJS_A. saved
# Protein 4MRT_C. saved
# Protein 4MRT_A. saved
# Protein 4MXV_B. saved
# Protein 4MXV_FE. saved
# Protein 4NIQ_C. saved
# Protein 4NIQ_A. saved
# Protein 4NL9_C. saved
# Protein 4NL9_A. saved
# Protein 4PJ2_D. saved
# Protein 4PJ2_A. saved
# Protein 4POU_B. saved
# Protein 4POU_A. saved
# Protein 4PS4_A. saved
# Protein 4PS4_HL. saved
# Protein 4PZ6_Q. saved
# Protein 4PZ6_A. saved
# Protein 4Q6I_J. saved
# Protein 4Q6I_ED. saved
# Protein 4RGM_S. saved
# Protein 4RGM_HL. saved
# Protein 4TSB_A. saved
# Protein 4TSB_HL. saved
# Protein 4U0Q_B. saved
# Protein 4U0Q_A. saved
# Protein 4U97_B. saved
# Protein 4U97_A. saved
# Protein 4UI1_D. saved
# Protein 4UI1_A. saved
# Protein 4V0N_D. saved
# Protein 4V0N_C. saved
# Protein 4W6W_B. saved
# Protein 4W6W_A. saved
# Protein 4W6Y_B. saved
# Protein 4W6Y_A. saved
# Protein 4XLW_B. saved
# Protein 4XLW_A. saved
# Protein 4XNZ_D. saved
# Protein 4XNZ_EF. saved
# Protein 4YDI_G. saved
# Protein 4YDI_HL. saved
# Protein 4YDL_G. saved
# Protein 4YDL_HL. saved
# Protein 4YEB_B. saved
# Protein 4YEB_A. saved
# Protein 4YK4_A. saved
# Protein 4YK4_CB. saved
# Protein 4YVQ_C. saved
# Protein 4YVQ_A. saved
# Protein 4YWC_C. saved
# Protein 4YWC_A. saved
# Protein 4Z5R_N. saved
# Protein 4Z5R_BA. saved
# Protein 4ZGQ_B. saved
# Protein 4ZGQ_A. saved
# Protein 4ZII_C. saved
# Protein 4ZII_A. saved
# Protein 4ZLT_F. saved
# Protein 4ZLT_B. saved
# Protein 4ZRK_E. saved
# Protein 4ZRK_A. saved
# Protein 4ZXB_E. saved
# Protein 4ZXB_CD. saved
# Protein 5B78_B. saved
# Protein 5B78_A. saved
# Protein 5C3F_B. saved
# Protein 5C3F_A. saved
# Protein 5CYK_B. saved
# Protein 5CYK_A. saved
# Protein 5D1K_B. saved
# Protein 5D1K_A. saved
# Protein 5D5M_B. saved
# Protein 5D5M_A. saved
# Protein 5D70_A. saved
# Protein 5D70_HL. saved
# Protein 5D71_A. saved
# Protein 5D71_HL. saved
# Protein 5DFW_H. saved
# Protein 5DFW_A. saved
# Protein 5DJT_B. saved
# Protein 5DJT_A. saved
# Protein 5DMJ_B. saved
# Protein 5DMJ_A. saved
# Protein 5E6P_B. saved
# Protein 5E6P_A. saved
# Protein 5FB8_C. saved
# Protein 5FB8_BA. saved
# Protein 5HI5_A. saved
# Protein 5HI5_CD. saved
# Protein 5IP4_E. saved
# Protein 5IP4_A. saved
# Protein 5KVD_E. saved
# Protein 5KVD_HL. saved
# Protein 5L6Y_C. saved
# Protein 5L6Y_HL. saved
# Protein 5LWY_A. saved
# Protein 5LWY_HL. saved
# Protein 5MES_A. saved
# Protein 5MES_HL. saved
# Protein 5MHR_C. saved
# Protein 5MHR_KJ. saved
# Protein 5MO9_X. saved
# Protein 5MO9_HL. saved
# Protein 5SV3_B. saved
# Protein 5SV3_A. saved
# Protein 5SZK_B. saved
# Protein 5SZK_A. saved
# Protein 5T29_O. saved
# Protein 5T29_HL. saved
# Protein 5T33_G. saved
# Protein 5T33_HL. saved
# Protein 5TH9_A. saved
# Protein 5TH9_HL. saved
# Protein 5USL_A. saved
# Protein 5USL_BC. saved
# Protein 5YOY_C. saved
# Protein 5YOY_HE. saved
# Protein 6B0A_A. saved
# Protein 6B0A_HL. saved
# Protein 6BCK_G. saved
# Protein 6BCK_HL. saved
# Protein 6BF4_A. saved
# Protein 6BF4_BC. saved
# Protein 6CK9_B. saved
# Protein 6CK9_DE. saved
# Protein 6CMG_A. saved
# Protein 6CMG_CB. saved

# %% [markdown]
# ### Check what there is in the directory and visualize

# %%
dest_dir = 'C:/Users/david/pyproj/pyg/adl/surfaces_graphs_iface/'
list_dest_dir = os.listdir(dest_dir)

complex_names = [] 
for name in os.listdir(dest_dir):
    if name[0:4] not in complex_names:
        complex_names.append(name[0:4])

# %%
### Import the two files corresponding to that complex

complex = complex_names[3]
print(complex)

import fnmatch
complex_filenames = fnmatch.filter(list_dest_dir, complex+'*')
print(complex_filenames)
# Out:
# 1BK6
# ['1BK6_B.pkl', '1BK6_E.pkl']

# %%
from helper_functions import load_object

subunit1 = load_object(dest_dir + complex_filenames[0])
subunit2 = load_object(dest_dir + complex_filenames[1])

# %%
subunit1.iface_center
# Out:
# (4833, array([57.1716, 35.6882, 22.4021], dtype=float32))

# %%
subunit1.iface_idx
# Out:
# [47,
#  53,
#  319,
#  396,
#  414,
#  484,
#  544,
#  624,
#  653,
#  660,
#  668,
#  735,
#  810,
#  951,
#  970,
#  995,
#  1000,
#  1096,
#  1235,
#  1254,
#  1265,
#  1280,
#  1298,
#  1376,
#  1383,
#  1462,
#  1554,
#  1598,
#  1652,
#  1754,
#  1847,
#  1904,
#  1977,
#  2058,
#  2091,
#  2096,
#  2148,
#  2240,
#  2252,
#  2254,
#  2303,
#  2531,
#  2582,
#  2885,
#  2921,
#  2958,
#  3027,
#  3052,
#  3091,
#  3110,
#  3162,
#  3199,
#  3228,
#  3284,
#  3313,
#  3315,
#  3324,
#  3397,
#  3403,
#  3435,
#  3456,
#  3584,
#  3625,
#  3638,
#  3656,
#  3731,
#  3741,
#  3744,
#  3858,
#  3941,
#  3954,
#  3998,
#  4111,
#  4129,
#  4181,
#  4248,
#  4326,
#  4333,
#  4399,
#  4427,
#  4447,
#  4533,
#  4555,
#  4573,
#  4668,
#  4673,
#  4682,
#  4697,
#  4818,
#  4833,
#  4908,
#  5038,
#  5052,
#  5112,
#  5134,
#  5190,
#  5191,
#  5354,
#  5363,
#  5404,
#  5485,
#  5512,
#  5582,
#  5626,
#  5627,
#  5635,
#  5642,
#  5682,
#  5689,
#  5861,
#  5886,
#  5921,
#  6070,
#  6104,
#  6186,
#  6207,
#  6356,
#  6393,
#  6450,
#  6454,
#  6530,
#  6572,
#  6606,
#  6617,
#  6676,
#  6710,
#  6711,
#  6717,
#  6775,
#  6827,
#  6860,
#  6902,
#  6918,
#  6947,
#  6958,
#  6983,
#  7018,
#  7038,
#  7066,
#  7133,
#  7235,
#  7253,
#  7290]

# %%
subunit1.iface_pos.shape
# Out:
# (143, 3)

# %% [markdown]
# ### Visualize subunit 1

# %%
from f_visualize_pointcloud import visualize_pointcloud

colors_subunit1 = np.zeros_like(subunit1.pos)
colors_subunit1[:] = [1,0,0]
colors_subunit1[subunit1.iface_idx] = [0,0,1]
colors_subunit1[subunit1.iface_center[0]] = [0,1,0]

visualize_pointcloud(subunit1.pos, colors = colors_subunit1)
# Out:
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.

# %% [markdown]
# ### Visualize Subunit 2

# %%
from f_visualize_pointcloud import visualize_pointcloud

colors_subunit2 = np.zeros_like(subunit2.pos)
colors_subunit2[:] = [1,0,0]
colors_subunit2[subunit2.iface_idx] = [0,0,1]
colors_subunit2[subunit2.iface_center[0]] = [0,1,0]

visualize_pointcloud(subunit2.pos, colors = colors_subunit2)

# %% [markdown]
# ### Visualize the complex

# %%
merged_coords = np.concatenate((subunit1.pos, subunit2.pos))
merged_colors = np.concatenate((colors_subunit1, colors_subunit2))

# %%
visualize_pointcloud(merged_coords, colors = merged_colors)
# Out:
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
